# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Đường dẫn ảnh
my_path = 'E:\\thigiacmaytinh\\hinhanh\\03.jpg'
# Đọc ảnh
im = Image.open(my_path)
plt.imshow(im)

# %%
# chuyển sang ảnh xám
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[53 53 53 ... 40 41 41]
#  [53 53 53 ... 40 41 41]
#  [52 52 52 ... 40 41 41]
#  ...
#  [38 39 39 ... 68 69 70]
#  [37 38 38 ... 67 68 69]
#  [37 38 38 ... 66 67 68]]

# %%
# tạo một hình vẽ mới
plt.figure()
plt.hist(im_array.flatten(), bins=6)
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
# làm nổi bật đường biên
plt.figure()
plt.gray()
plt.contour(im_gray, orgin='image')
plt.show()
# Out:
# C:\Users\Monkey\AppData\Local\Temp\ipykernel_11004\2985728432.py:4: UserWarning: The following kwargs were not used by contour: 'orgin'
#   plt.contour(im_gray, orgin='image')

# %%
# đường dân ảnh
my_path = 'C:\\Users\\Monkey\\Documents\\hinhanh\\02.jpg'
# đọc ảnh và hiển thị ảnh với trục tạo độ
im= Image.open(my_path).convert('L')

# hiển thị ảnh trên trục tạo độ
plt.imshow(im)

# tạo một ình vẽ mới
plt.figure()

# đặt màu sắc là xám
plt.gray()

# vẽ biểu đồ đường biên (contour) của ảnh
plt.contour(im, origin="image")

# đảm bảo tỷ lệ trục x và trục y trên biểu đồ là bằng nhau
plt.axis('equal')

# hiển thị ảnh
plt.show()
