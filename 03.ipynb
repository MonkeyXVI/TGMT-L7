# %%
from PIL import Image
from imgtool import *

# %%
#Đường dẫn ảnh
my_path = 'E:\\thigiacmaytinh\\hinhanh\\04.jpg'

# %%
# Doc anh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=190x266>

# %%
# Kích thước ban đầu 
print(img.size)
# Out:
# (190, 266)

# %%
# thay đỏi lích thước của ảnh
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
#thay đổi kích thước
thumbnail_size= (50,50)
img.thumbnail(thumbnail_size)
display (img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=36x50>
